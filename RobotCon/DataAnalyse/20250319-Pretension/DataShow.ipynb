# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.ticker as ticker
from matplotlib.ticker import MultipleLocator
from matplotlib.gridspec import GridSpec
from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d.art3d import Line3DCollection
from matplotlib.colors import Normalize
import matplotlib.cm as cm
import matplotlib.font_manager as fm
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
from mpl_toolkits.mplot3d import Axes3D

# 设置全局字体为 Times New Roman
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = 'Times New Roman'

# %% [markdown]
# contact=[210, 224]

# %%
loss_np = np.loadtxt(f'loss_list1.csv', delimiter=',')
loss_con_np = np.loadtxt(f'loss_con_list1.csv', delimiter=',')

# %%
plot_step_num = loss_np.shape[0]
fig = plt.figure(figsize=(5.2, 3), dpi=150)
gs = GridSpec(1, 1, figure=fig)

step_num = loss_np.shape[0]
axs_loss = fig.add_subplot(gs[0, :])
axs_loss.plot(loss_con_np[:], marker='.', markerfacecolor='white', linestyle='-', linewidth=2, color='black')
axs_loss.set_title('Loss Curve', fontsize=16, fontname='Times New Roman')
axs_loss.set_xlabel('Time Step', fontsize=14, fontname='Times New Roman')
axs_loss.set_ylabel('Loss', fontsize=14, fontname='Times New Roman')
axs_loss.set_xlim([-1, plot_step_num])
axs_loss.xaxis.set_major_locator(MultipleLocator(20))
axs_loss.ticklabel_format(axis='y', style='sci', scilimits=(-1, 1), useLocale=False, useMathText=True)
axs_loss.grid(True)

plt.tight_layout()
fig.savefig(f'loss.svg', transparent=True, dpi=300)

# %% [markdown]
# contact=[150, 224]

# %%
loss_np = np.loadtxt(f'loss_list2.csv', delimiter=',')
loss_con_np = np.loadtxt(f'loss_con_list2.csv', delimiter=',')

# %%
plot_step_num = loss_np.shape[0]
fig = plt.figure(figsize=(5.2, 3), dpi=150)
gs = GridSpec(1, 1, figure=fig)

step_num = loss_np.shape[0]
axs_loss = fig.add_subplot(gs[0, :])
axs_loss.plot(loss_np[:], marker='.', markerfacecolor='white', linestyle='-', linewidth=2, color='black')
axs_loss.set_title('Loss Curve', fontsize=16, fontname='Times New Roman')
axs_loss.set_xlabel('Time Step', fontsize=14, fontname='Times New Roman')
axs_loss.set_ylabel('Loss', fontsize=14, fontname='Times New Roman')
axs_loss.set_xlim([-1, plot_step_num])
axs_loss.xaxis.set_major_locator(MultipleLocator(20))
axs_loss.ticklabel_format(axis='y', style='sci', scilimits=(-1, 1), useLocale=False, useMathText=True)
axs_loss.grid(True)

plt.tight_layout()
fig.savefig(f'loss.svg', transparent=True, dpi=300)

# %% [markdown]
# contact=[180, 149]

# %%
loss_np = np.loadtxt(f'loss_list3.csv', delimiter=',')
loss_con_np = np.loadtxt(f'loss_con_list3.csv', delimiter=',')

# %%
plot_step_num = loss_np.shape[0]
fig = plt.figure(figsize=(5.2, 3), dpi=150)
gs = GridSpec(1, 1, figure=fig)

step_num = loss_np.shape[0]
axs_loss = fig.add_subplot(gs[0, :])
axs_loss.plot(loss_np[:], marker='.', markerfacecolor='white', linestyle='-', linewidth=2, color='black')
axs_loss.set_title('Loss Curve', fontsize=16, fontname='Times New Roman')
axs_loss.set_xlabel('Time Step', fontsize=14, fontname='Times New Roman')
axs_loss.set_ylabel('Loss', fontsize=14, fontname='Times New Roman')
axs_loss.set_xlim([-1, plot_step_num])
axs_loss.xaxis.set_major_locator(MultipleLocator(20))
axs_loss.ticklabel_format(axis='y', style='sci', scilimits=(-1, 1), useLocale=False, useMathText=True)
axs_loss.grid(True)

plt.tight_layout()
fig.savefig(f'loss.svg', transparent=True, dpi=300)

# %% [markdown]
# contact=[180, 194]

# %%
loss_np = np.loadtxt(f'loss_list4.csv', delimiter=',')
loss_con_np = np.loadtxt(f'loss_con_list4.csv', delimiter=',')

# %%
plot_step_num = loss_np.shape[0]
fig = plt.figure(figsize=(5.2, 3), dpi=150)
gs = GridSpec(1, 1, figure=fig)

step_num = loss_np.shape[0]
axs_loss = fig.add_subplot(gs[0, :])
axs_loss.plot(loss_np[:], marker='.', markerfacecolor='white', linestyle='-', linewidth=2, color='black')
axs_loss.set_title('Loss Curve', fontsize=16, fontname='Times New Roman')
axs_loss.set_xlabel('Time Step', fontsize=14, fontname='Times New Roman')
axs_loss.set_ylabel('Loss', fontsize=14, fontname='Times New Roman')
axs_loss.set_xlim([-1, plot_step_num])
axs_loss.xaxis.set_major_locator(MultipleLocator(20))
axs_loss.ticklabel_format(axis='y', style='sci', scilimits=(-1, 1), useLocale=False, useMathText=True)
axs_loss.grid(True)

plt.tight_layout()
fig.savefig(f'loss.svg', transparent=True, dpi=300)

# %% [markdown]
# contact=[180, 179]
